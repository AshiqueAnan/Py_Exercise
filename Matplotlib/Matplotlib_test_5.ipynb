# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
X = np.random.randint(0, 20, 5)

# %%
Y = np.random.randint(0, 20, 5)

# %%
X
# Out:
# array([ 3,  8, 14, 18, 16])

# %%
Y
# Out:
# array([3, 3, 0, 3, 0])

# %%
Fig = plt.figure()

# %%
Axis = Fig.add_axes([0,0,1,1])

# %%
Axis.plot(X,Y, "red", lw = 5, ls = "dashdot", marker = '8', markersize = 10, markerfacecolor = "blue", markeredgecolor = "yellow", markeredgewidth = 3)

# %%
Fig
