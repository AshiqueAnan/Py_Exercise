# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
Data_flight = pd.read_csv("flight_details.csv")

# %%
Data_flight
# Out:
#      Years     Months  Passengers
# 0     2001    January         112
# 1     2001   February         118
# 2     2001      March         132
# 3     2001      April         129
# 4     2001        May         121
# ..     ...        ...         ...
# 139   2012     August         606
# 140   2012  September         508
# 141   2012    October         461
# 142   2012   November         390
# 143   2012   December         432
#
# [144 rows x 3 columns]

# %%
Sorted_data = Data_flight.pivot(index = "Months", columns = "Years", values = "Passengers")

# %%
Sorted_data
# Out:
# Years      2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# Months
# April       129   135   163   181   235   227   269   313   348   348   396
# August      148   170   199   242   272   293   347   405   467   505   559
# December    118   140   166   194   201   229   278   306   336   337   405
# February    118   126   150   180   196   188   233   277   301   318   342
# January     112   115   145   171   196   204   242   284   315   340   360
# July        148   170   199   230   264   302   364   413   465   491   548
# June        135   149   178   218   243   264   315   374   422   435   472
# March       132   141   178   193   236   235   267   317   356   362   406
# May         121   125   172   183   229   234   270   318   355   363   420
# November    104   114   146   172   180   203   237   271   305   310   362
# October     119   133   162   191   211   229   274   306   347   359   407
# ...

# %%
sns.set()
plt.figure(dpi = 120)
sns.heatmap(data = Sorted_data)
plt.title("Heatmap Data of Flights")
plt.show()

# %%
sns.set()
plt.figure(dpi = 120)
sns.heatmap(data = Sorted_data, cmap = sns.light_palette("blue", as_cmap = True , reverse = True))
plt.title("Heatmap Data of Flights In BLUE MFFFF")
plt.show()
